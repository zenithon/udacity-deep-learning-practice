# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [01:00, 515KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

len_words = len(int_words)
word_count = Counter(int_words)
threshold = 1e-5
word_freq = {word: count / len_words for word, count in word_count.items()}
p_drop = {word: 1 - np.sqrt(threshold / word_freq[word]) for word in word_freq}

train_words = [word for word in int_words if random.random() < (1 - p_drop[word])] # The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    s_idx = idx - R if idx-R > 0 else 0
    e_idx = idx + R if idx+R < len(words) else len(words)
    targets = set(words[s_idx: idx] + words[idx+1:e_idx+1])
    
    return list(targets)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros([n_vocab])) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: `checkpoints' 디렉토리를 만들 수 없습니다: 파일이 있습니다

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6491 0.1329 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6243 0.0738 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4797 0.0737 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6072 0.0739 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5031 0.0734 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5476 0.0734 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5365 0.0731 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5694 0.0731 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4676 0.0730 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4520 0.0730 sec/batch
# Nearest to that: woodcarver, remodeling, haines, bernardo, dawn, ussr, relates, sprague,
# Nearest to who: aching, gibraltarians, specific, finds, vatsetis, mithras, buster, polonium,
# Nearest to these: kendal, spellman, side, sarai, catoctin, alpacas, hales, locator,
# Nearest to however: alighieri, cows, contributory, suppressed, typological, anglophone, lenstra, pathogens,
# Nearest to in: polled, petition, decimalisation, toon, humidity, pueblo, charger, konqueror,
# Nearest to by: humidity, biochemistry, grantham, aretha, tome, seasoned, pardoned, parts,
# Nearest to d: delius, curta, modification, christophe, embodied, philippines, tcp, chamada,
# Nearest to may: staking, inflicting, drummer, je, emptying, artiodactyla, recurring, underwrite,
# Nearest to professional: fictions, endogenous, valdemar, khagan, profound, adapters, slug, eurydice,
# Nearest to animals: woolley, rotation, proceeds, ewing, cena, lawn, removes, burrito,
# Nearest to powers: rumored, outages, midday, oranges, pavements, piping, junta, secker,
# Nearest to nobel: transversal, aviation, mohel, tellurium, indeterminate, sikorski, mandaic, glycoprotein,
# Nearest to liberal: lauper, andriessen, lottie, morihei, erected, correspondent, furtado, caria,
# Nearest to proposed: interphase, apparently, altar, thorpe, maige, stereochemistry, papandreou, catatonic,
# Nearest to universe: grams, boyband, daimlerchrysler, udo, unopposed, chico, feudatories, commend,
# Nearest to recorded: ephraim, rawlinson, teams, meza, imager, gastroenterology, disruptions, falklands,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4476 0.0742 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3945 0.0739 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3141 0.0735 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2503 0.0731 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2002 0.0732 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1522 0.0731 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0833 0.0731 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0528 0.0731 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9919 0.0732 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9807 0.0732 sec/batch
# Nearest to that: relates, filming, remodeling, ussr, measurable, dawn, generation, woodcarver,
# Nearest to who: finds, aching, specific, fans, hobbs, chose, involvement, polonium,
# Nearest to these: side, amounts, recent, spellman, contend, perplexed, many, frail,
# Nearest to however: alighieri, allows, suppressed, communist, typological, anglophone, cows, lagging,
# Nearest to in: petition, polled, humidity, engineers, economic, toon, towards, century,
# Nearest to by: parts, humidity, biochemistry, tome, wounds, magical, seasoned, four,
# Nearest to d: modification, philippines, delius, embodied, takeovers, raj, curta, linehan,
# Nearest to may: staking, inflicting, drummer, recurring, family, t, religion, color,
# Nearest to professional: weapons, contain, caused, eighth, profound, point, endogenous, valdemar,
# Nearest to animals: rotation, illustrated, time, woolley, proceeds, burrito, ewing, removes,
# Nearest to powers: build, probable, there, oranges, midday, rumored, often, cyberspace,
# Nearest to nobel: aviation, transversal, tellurium, indeterminate, mohel, sikorski, her, manufacture,
# Nearest to liberal: lauper, erected, andriessen, presidency, correspondent, lottie, feel, morihei,
# Nearest to proposed: interphase, altar, apparently, psionic, thorpe, iraqi, avc, giraldus,
# Nearest to universe: grams, boyband, daimlerchrysler, syncretism, concentrate, feudatories, mistaken, commend,
# Nearest to recorded: teams, ephraim, rawlinson, growing, month, filming, dr, plural,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9503 0.0744 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9048 0.0739 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8708 0.0743 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8879 0.0740 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8099 0.0740 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8103 0.0740 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7826 0.0738 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7872 0.0739 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7865 0.0743 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7706 0.0745 sec/batch
# Nearest to that: filming, relates, remodeling, supervise, dawn, submitted, garrison, measurable,
# Nearest to who: aching, finds, letter, deserves, involvement, indirect, steeped, hobbs,
# Nearest to these: side, spellman, amounts, exposing, perplexed, tijuana, contend, simulated,
# Nearest to however: alighieri, suppressed, allows, typological, anglophone, communist, pathogens, cows,
# Nearest to in: petition, polled, engineers, toon, humidity, economic, decimalisation, categories,
# Nearest to by: parts, humidity, tome, biochemistry, pardoned, grantham, wounds, catholics,
# Nearest to d: philippines, modification, christophe, delius, curta, takeovers, raj, embodied,
# Nearest to may: staking, inflicting, drummer, religion, rushing, possessed, iterations, aten,
# Nearest to professional: profound, weapons, fictions, disclosed, endogenous, caused, contain, eighth,
# Nearest to animals: rotation, illustrated, removes, time, proceeds, woolley, discover, burrito,
# Nearest to powers: junta, rumored, independence, biosphere, bank, probable, build, midday,
# Nearest to nobel: aviation, transversal, tellurium, manufacture, indeterminate, her, mohel, sikorski,
# Nearest to liberal: lauper, erected, presidency, correspondent, andriessen, feel, caria, morihei,
# Nearest to proposed: interphase, altar, apparently, iraqi, psionic, causation, administration, algae,
# Nearest to universe: grams, daimlerchrysler, concentrate, syncretism, probes, mistaken, boyband, feudatories,
# Nearest to recorded: teams, ephraim, rawlinson, month, filming, falklands, imager, elena,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8010 0.0757 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7547 0.0761 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7167 0.0757 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7153 0.0757 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7442 0.0760 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6793 0.0759 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7055 0.0760 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7443 0.0758 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7252 0.0763 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6351 0.0759 sec/batch
# Nearest to that: relates, niccol, remodeling, filming, supervise, haines, dawn, configured,
# Nearest to who: aching, steeped, mithras, hobbs, letter, polonium, deserves, finds,
# Nearest to these: side, spellman, exposing, amounts, kendal, perplexed, tijuana, finely,
# Nearest to however: pathogens, alighieri, suppressed, anglophone, cows, communist, typological, contributory,
# Nearest to in: petition, polled, pueblo, decimalisation, economic, toon, infinitives, engineers,
# Nearest to by: parts, tome, humidity, grantham, aretha, wounds, pardoned, biochemistry,
# Nearest to d: philippines, christophe, delius, curta, zero, modification, massacres, takeovers,
# Nearest to may: staking, inflicting, religion, underwrite, drummer, emptying, rushing, possessed,
# Nearest to professional: profound, fictions, endogenous, khagan, weapons, disclosed, scandals, southernmost,
# Nearest to animals: rotation, removes, woolley, illustrated, time, proceeds, discover, socio,
# Nearest to powers: junta, rumored, independence, bank, piping, hooke, midday, lenin,
# Nearest to nobel: aviation, transversal, tellurium, manufacture, businessman, glycoprotein, sikorski, berber,
# Nearest to liberal: erected, lauper, presidency, andriessen, correspondent, sadd, caria, tightened,
# Nearest to proposed: interphase, altar, apparently, iraqi, psionic, causation, thorpe, algae,
# Nearest to universe: grams, daimlerchrysler, concentrate, probes, feudatories, boyband, commend, unopposed,
# Nearest to recorded: ephraim, teams, rawlinson, month, meza, upload, imager, battery,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6842 0.0764 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6630 0.0758 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6420 0.0759 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6159 0.0758 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6337 0.0762 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6399 0.0766 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6188 0.0933 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5272 0.0756 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5394 0.0759 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5098 0.0761 sec/batch
# Nearest to that: relates, niccol, remodeling, filming, supervise, configured, dawn, measurable,
# Nearest to who: aching, steeped, enumerates, berated, deserves, chose, evoking, mithras,
# Nearest to these: side, spellman, amounts, kendal, exposing, finely, tijuana, folder,
# Nearest to however: pathogens, contributory, suppressed, alighieri, typological, anglophone, lenstra, cows,
# Nearest to in: linguistically, petition, decimalisation, toon, polled, lawlessness, pueblo, infinitives,
# Nearest to by: aretha, parts, grantham, humidity, tome, sql, biochemistry, squirrels,
# Nearest to d: christophe, author, philippines, williams, sculptor, actress, physicist, zero,
# Nearest to may: inflicting, staking, whewell, religion, kinematics, rushing, underwrite, loch,
# Nearest to professional: fictions, profound, khagan, scandals, weapons, endogenous, southernmost, ming,
# Nearest to animals: removes, rotation, mechanization, woolley, time, burrito, socio, discover,
# Nearest to powers: junta, rumored, independence, bank, piping, hooke, midday, lenin,
# Nearest to nobel: writer, composer, aviation, transversal, recipient, businessman, footballer, physiology,
# Nearest to liberal: erected, lauper, andriessen, presidency, sadd, tightened, correspondent, lottie,
# Nearest to proposed: interphase, altar, apparently, psionic, algae, thorpe, causation, indifference,
# Nearest to universe: grams, daimlerchrysler, concentrate, forms, unopposed, boyband, syncretism, probes,
# Nearest to recorded: ephraim, teams, rawlinson, upload, month, meza, song, downstream,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5206 0.0769 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5340 0.0761 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4633 0.0763 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5280 0.0762 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5093 0.0765 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4911 0.0763 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4322 0.0763 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3951 0.0764 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4240 0.0762 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4267 0.0763 sec/batch
# Nearest to that: relates, remodeling, supervise, segmentation, measurable, niccol, configured, registering,
# Nearest to who: enumerates, aching, mithras, steeped, berated, deserves, chose, tobruk,
# Nearest to these: side, spellman, amounts, kendal, exposing, petitioner, finely, simulated,
# Nearest to however: pathogens, contributory, anglophone, alighieri, suppressed, lenstra, manipulating, communist,
# Nearest to in: decimalisation, petition, toon, linguistically, economic, polled, lawlessness, pueblo,
# Nearest to by: humidity, parts, tome, grantham, squirrels, aretha, neurobiological, unsustainable,
# Nearest to d: christophe, delius, cruz, philippines, williams, raj, philistine, curta,
# Nearest to may: inflicting, staking, whewell, yahweh, realities, bourget, headwear, underwrite,
# Nearest to professional: fictions, profound, baseball, khagan, scandals, ming, capes, montenegrins,
# Nearest to animals: removes, rotation, mechanization, lipid, discover, woolley, time, altruistic,
# Nearest to powers: junta, independence, rumored, bank, piping, hooke, midday, macedonians,
# Nearest to nobel: composer, writer, aviation, transversal, recipient, businessman, playwright, footballer,
# Nearest to liberal: erected, andriessen, presidency, democrats, lauper, sadd, tightened, lottie,
# Nearest to proposed: interphase, altar, apparently, psionic, algae, iraqi, causation, indifference,
# Nearest to universe: grams, nucleosynthesis, biology, boyband, concentrate, flowers, walnuts, daimlerchrysler,
# Nearest to recorded: ephraim, rawlinson, song, teams, month, downstream, upload, gloucestershire,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4304 0.0773 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4040 0.0764 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4155 0.0764 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4202 0.0765 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4230 0.0764 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4262 0.0764 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3972 0.0763 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3826 0.0763 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3970 0.0765 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3823 0.0763 sec/batch
# Nearest to that: relates, awaiting, measurable, reforms, remodeling, supervise, segmentation, filming,
# Nearest to who: enumerates, chose, aching, mithras, steeped, king, deserves, grandfather,
# Nearest to these: spellman, side, amounts, exposing, kendal, petitioner, rumi, folder,
# Nearest to however: pathogens, manipulating, suppressed, lenstra, anglophone, contributory, cows, typological,
# Nearest to in: petition, decimalisation, toon, linguistically, join, polled, pueblo, easterners,
# Nearest to by: tome, squirrels, humidity, grantham, parts, neurobiological, unsustainable, aretha,
# Nearest to d: christophe, delius, philistine, williams, philippines, cruz, curta, raj,
# Nearest to may: inflicting, staking, whewell, bourget, yahweh, realities, pedagogic, serviceable,
# Nearest to professional: fictions, baseball, khagan, profound, scandals, ming, braves, unicef,
# Nearest to animals: removes, rotation, lipid, mechanization, traditions, discover, organisms, illustrated,
# Nearest to powers: junta, independence, rumored, piping, bank, hooke, outages, macedonians,
# Nearest to nobel: businessman, composer, aviation, recipient, footballer, transversal, writer, physiology,
# Nearest to liberal: democrats, erected, andriessen, presidency, sadd, lauper, tightened, caria,
# Nearest to proposed: interphase, algae, altar, harboring, psionic, tubular, apparently, ghosh,
# Nearest to universe: grams, nucleosynthesis, biology, daimlerchrysler, probes, boyband, unphysical, walnuts,
# Nearest to recorded: ephraim, song, rawlinson, downstream, hexagram, month, upload, apes,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3375 0.0771 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3767 0.0764 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3422 0.0764 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3896 0.0766 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3913 0.0766 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3805 0.0767 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4116 0.0769 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3892 0.0767 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3249 0.0770 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3424 0.0765 sec/batch
# Nearest to that: awaiting, relates, remodeling, until, reforms, supervise, submitted, filming,
# Nearest to who: mithras, chose, king, steeped, berated, aching, enumerates, sari,
# Nearest to these: spellman, side, amounts, exposing, petitioner, kendal, immanent, mindat,
# Nearest to however: pathogens, suppressed, anglophone, manipulating, contributory, typological, within, interlanguage,
# Nearest to in: decimalisation, petition, toon, ribeiro, linguistically, easterners, pueblo, polled,
# Nearest to by: squirrels, tome, grantham, unsustainable, parts, humidity, aretha, impeached,
# Nearest to d: delius, philistine, christophe, curta, monoxide, cruz, gattaca, williams,
# Nearest to may: inflicting, staking, whewell, yahweh, declaratory, contexts, realities, kinematics,
# Nearest to professional: baseball, fictions, braves, unicef, awarded, cookbookwiki, khagan, profound,
# Nearest to animals: removes, lipid, mechanization, illustrated, rotation, organisms, socio, traditions,
# Nearest to powers: independence, junta, bank, piping, rumored, macedonians, president, senators,
# Nearest to nobel: businessman, physiology, recipient, aviation, composer, transversal, lazare, physician,
# Nearest to liberal: democrats, sadd, andriessen, erected, presidency, tightened, lauper, authority,
# Nearest to proposed: interphase, ghosh, harboring, algae, interdiction, tubular, iraqi, psionic,
# Nearest to universe: grams, probes, daimlerchrysler, nucleosynthesis, boyband, impersonal, derivational, biology,
# Nearest to recorded: ephraim, song, rawlinson, hexagram, gastroenterology, downstream, apes, upload,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3426 0.0772 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2970 0.0768 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3805 0.0766 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3730 0.0764 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3840 0.0767 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2922 0.0767 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3158 0.0766 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3281 0.0767 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2294 0.0770 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2863 0.0769 sec/batch
# Nearest to that: awaiting, reforms, filming, relates, remodeling, submitted, until, supervise,
# Nearest to who: aching, chose, mithras, steeped, berated, enumerates, tobruk, adduce,
# Nearest to these: spellman, side, petitioner, exposing, amounts, immanent, kendal, number,
# Nearest to however: pathogens, suppressed, contributory, outright, manipulating, typological, interlanguage, panyu,
# Nearest to in: decimalisation, petition, toon, pueblo, well, miniscule, oiler, ribeiro,
# Nearest to by: aretha, impeached, squirrels, grantham, laypersons, parts, tome, in,
# Nearest to d: sculptor, delius, politician, christophe, conductor, physicist, frye, romain,
# Nearest to may: staking, inflicting, whewell, declaratory, kinematics, artiodactyla, headwear, contexts,
# Nearest to professional: baseball, braves, fictions, awarded, unicef, ming, cookbookwiki, khagan,
# Nearest to animals: lipid, removes, humans, mechanization, traditions, organisms, altruistic, socio,
# Nearest to powers: independence, junta, piping, lenin, bank, head, rumored, plenipotentiary,
# Nearest to nobel: physiology, recipient, physician, chemist, businessman, composer, lazare, laureate,
# Nearest to liberal: democrats, sadd, andriessen, tightened, presidency, endorse, erected, caria,
# Nearest to proposed: interphase, ghosh, interdiction, harboring, iraqi, athletes, stereochemistry, crossbar,
# Nearest to universe: grams, impersonal, probes, boyband, nucleosynthesis, daimlerchrysler, derivational, walnuts,
# Nearest to recorded: ephraim, song, downstream, rawlinson, hexagram, gloucestershire, gastroenterology, apes,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3027 0.0776 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2829 0.0768 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3571 0.0346 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2490 0.0766 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2718 0.0767 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2037 0.0766 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2106 0.0766 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1940 0.0764 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2154 0.0765 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1785 0.0761 sec/batch
# Nearest to that: remodeling, reforms, submitted, until, awaiting, relates, supervise, cautions,
# Nearest to who: mithras, aching, berated, adduce, enumerates, tobruk, grandfather, steeped,
# Nearest to these: spellman, side, petitioner, sarai, exposing, amounts, rheims, studd,
# Nearest to however: pathogens, manipulating, interlanguage, panyu, suppressed, typological, lenstra, outright,
# Nearest to in: decimalisation, petition, the, pueblo, presidentially, easterners, miniscule, linguistically,
# Nearest to by: squirrels, humidity, impeached, aretha, in, were, unsustainable, tome,
# Nearest to d: delius, hone, christophe, sculptor, politician, conductor, curta, romain,
# Nearest to may: staking, inflicting, whewell, declaratory, kinematics, contexts, serviceable, pedagogic,
# Nearest to professional: baseball, braves, fictions, awarded, unicef, cookbookwiki, ming, jumped,
# Nearest to animals: humans, removes, lipid, traditions, mechanization, socio, illustrated, organisms,
# Nearest to powers: junta, independence, piping, lenin, rumored, sentencing, macedonians, hooke,
# Nearest to nobel: physiology, recipient, chemist, businessman, physician, lazare, composer, laureate,
# Nearest to liberal: democrats, andriessen, sadd, tightened, endorse, presidency, caria, opposition,
# Nearest to proposed: interphase, ghosh, stereochemistry, interdiction, harboring, iraqi, ethers, algae,
# Nearest to universe: impersonal, abrahamic, grams, derivational, probes, boyband, unphysical, friend,
# Nearest to recorded: song, ephraim, downstream, hexagram, apes, rawlinson, gastroenterology, meza,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2374 0.0769 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2435 0.0763 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2304 0.0763 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1339 0.0764 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1826 0.0762 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1753 0.0759 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1807 0.0763 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1879 0.0759 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2204 0.0764 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1804 0.0767 sec/batch
# Nearest to that: remodeling, filming, segmentation, awaiting, submitted, relates, measurable, registering,
# Nearest to who: mithras, berated, adduce, grandfather, fans, enumerates, steeped, aching,
# Nearest to these: spellman, petitioner, side, exposing, amounts, sarai, number, immanent,
# Nearest to however: manipulating, pathogens, panyu, interlanguage, lenstra, allows, islamists, outright,
# Nearest to in: petition, spherically, decimalisation, the, by, membrane, from, well,
# Nearest to by: squirrels, in, tome, humidity, unsustainable, impeached, parts, aretha,
# Nearest to d: delius, curta, monoxide, gattaca, hone, christophe, alphanumeric, oshawa,
# Nearest to may: staking, inflicting, serviceable, contexts, yahweh, nutrients, kinematics, does,
# Nearest to professional: baseball, braves, awarded, unicef, cookbookwiki, fictions, chosenness, joe,
# Nearest to animals: humans, lipid, removes, traditions, socio, mechanization, illustrated, organisms,
# Nearest to powers: junta, independence, lenin, piping, sentencing, rumored, legislate, plenipotentiary,
# Nearest to nobel: physiology, recipient, businessman, chemist, aviation, lazare, medicine, laureate,
# Nearest to liberal: democrats, andriessen, endorse, sadd, mps, coalition, tightened, presidency,
# Nearest to proposed: interphase, ghosh, stereochemistry, tubular, ethers, harboring, algae, sigmoid,
# Nearest to universe: nucleosynthesis, grams, impersonal, derivational, abrahamic, cosmological, friend, walnuts,
# Nearest to recorded: song, ephraim, downstream, apes, gastroenterology, hexagram, rawlinson, meza,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1890 0.0772 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2366 0.0768 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1462 0.0767 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1348 0.0769 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1694 0.0769 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2076 0.0767 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1938 0.0765 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1657 0.0759 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1352 0.0757 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.2165 0.0760 sec/batch
# Nearest to that: remodeling, filming, segmentation, awaiting, submitted, until, supervise, mismatch,
# Nearest to who: adduce, grandfather, mithras, berated, consultant, saw, enumerates, steeped,
# Nearest to these: spellman, petitioner, sarai, side, transferring, number, exposing, immanent,
# Nearest to however: panyu, manipulating, pathogens, interlanguage, islamists, crittenden, outright, figuring,
# Nearest to in: petition, spherically, the, pueblo, from, well, decimalisation, presidentially,
# Nearest to by: four, carabineros, impeached, squirrels, humidity, determination, tome, in,
# Nearest to d: delius, romain, hone, curta, gattaca, christophe, conductor, kearney,
# Nearest to may: inflicting, staking, kinematics, serviceable, yahweh, nutrients, declaratory, champs,
# Nearest to professional: baseball, awarded, unicef, braves, fictions, cookbookwiki, overstepped, asa,
# Nearest to animals: humans, lipid, organisms, removes, socio, illustrated, genetics, traditions,
# Nearest to powers: junta, independence, piping, sentencing, lenin, hooke, dominions, plenipotentiary,
# Nearest to nobel: physiology, recipient, chemist, businessman, medicine, aviation, lazare, physician,
# Nearest to liberal: democrats, andriessen, sadd, mps, endorse, tightened, coalition, electorate,
# Nearest to proposed: interphase, ghosh, tubular, harboring, ethers, interdiction, algae, stereochemistry,
# Nearest to universe: nucleosynthesis, cosmological, friend, abrahamic, impersonal, grams, derivational, probes,
# Nearest to recorded: song, ephraim, downstream, apes, gastroenterology, hexagram, meza, rawlinson,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1815 0.0769 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1856 0.0763 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1516 0.0762 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1933 0.0764 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1440 0.0760 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1350 0.0755 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1586 0.0760 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1423 0.0761 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1735 0.0762 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2174 0.0762 sec/batch
# Nearest to that: remodeling, submitted, filming, until, awaiting, reforms, supervise, far,
# Nearest to who: adduce, mithras, grandfather, saw, berated, profiting, steeped, tobruk,
# Nearest to these: spellman, petitioner, sarai, immanent, number, transferring, studd, rheims,
# Nearest to however: panyu, interlanguage, manipulating, crittenden, islamists, pathogens, figuring, outright,
# Nearest to in: the, of, from, petition, by, pueblo, presidentially, second,
# Nearest to by: in, carabineros, impeached, four, determination, aretha, were, mechs,
# Nearest to d: delius, romain, hone, jorge, christophe, curta, conductor, sculptor,
# Nearest to may: staking, inflicting, kinematics, leopoldo, champs, jes, declaratory, contexts,
# Nearest to professional: baseball, braves, unicef, awarded, cookbookwiki, fictions, managers, gilmore,
# Nearest to animals: humans, lipid, socio, microclimates, illustrated, pygmy, removes, organisms,
# Nearest to powers: junta, independence, piping, lenin, hooke, breitman, cuzco, head,
# Nearest to nobel: physiology, recipient, chemist, medicine, businessman, physician, prize, aviation,
# Nearest to liberal: democrats, andriessen, mps, sadd, endorse, lieberman, tightened, coalition,
# Nearest to proposed: interphase, ghosh, interdiction, ethers, tubular, stereochemistry, algae, mentewab,
# Nearest to universe: nucleosynthesis, cosmological, friend, abrahamic, impersonal, derivational, grams, mythological,
# Nearest to recorded: song, ephraim, downstream, apes, hexagram, rawlinson, gastroenterology, gloucestershire,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2290 0.0772 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1316 0.0764 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1172 0.0761 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1641 0.0766 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0405 0.0766 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1336 0.0765 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1271 0.0767 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1222 0.0766 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1636 0.0124 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1588 0.0763 sec/batch
# Nearest to that: remodeling, filming, far, until, awaiting, decry, supervise, segmentation,
# Nearest to who: adduce, grandfather, enumerates, mithras, risky, consultant, divest, berated,
# Nearest to these: spellman, petitioner, sarai, number, side, cephalon, transferring, immanent,
# Nearest to however: panyu, interlanguage, manipulating, crittenden, pathogens, rial, outright, islamists,
# Nearest to in: the, from, of, second, by, presidentially, is, petition,
# Nearest to by: carabineros, impeached, in, determination, squirrels, creation, hailstorm, judaean,
# Nearest to d: delius, romain, hone, conductor, curta, gattaca, sculptor, politician,
# Nearest to may: staking, inflicting, champs, kinematics, jes, contexts, artiodactyla, integer,
# Nearest to professional: baseball, braves, unicef, awarded, cookbookwiki, managers, overstepped, asa,
# Nearest to animals: humans, lipid, microclimates, genetics, lactation, illustrated, pygmy, mechanization,
# Nearest to powers: junta, independence, piping, hooke, cuzco, rumored, lenin, breitman,
# Nearest to nobel: physiology, recipient, chemist, aviation, medicine, prize, manufacturer, physician,
# Nearest to liberal: democrats, mps, andriessen, sadd, lieberman, endorse, coalition, tightened,
# Nearest to proposed: interphase, ghosh, stereochemistry, ethers, interdiction, tubular, comte, sigmoid,
# Nearest to universe: cosmological, abrahamic, nucleosynthesis, impersonal, friend, derivational, reality, mythological,
# Nearest to recorded: song, ephraim, downstream, apes, gloucestershire, tulane, meza, gastroenterology,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.1158 0.0773 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.1117 0.0766 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1052 0.0765 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0777 0.0764 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0544 0.0764 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0463 0.0767 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1061 0.0766 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0987 0.0767 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1168 0.0766 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0620 0.0765 sec/batch
# Nearest to that: remodeling, filming, until, far, supervise, extremal, obliging, registering,
# Nearest to who: adduce, enumerates, mithras, certificates, grandfather, risky, aide, divest,
# Nearest to these: spellman, petitioner, sarai, side, number, transferring, cephalon, immanent,
# Nearest to however: panyu, interlanguage, crittenden, manipulating, pathogens, rial, figuring, outright,
# Nearest to in: the, of, from, second, petition, by, is, known,
# Nearest to by: in, carabineros, determination, impeached, squirrels, four, parts, divider,
# Nearest to d: delius, hone, romain, gattaca, curta, ir, jorge, kearney,
# Nearest to may: staking, inflicting, champs, kinematics, integer, jes, contexts, yahweh,
# Nearest to professional: baseball, awarded, braves, unicef, overstepped, managers, cookbookwiki, subkey,
# Nearest to animals: humans, lipid, socio, genetics, pankhurst, microclimates, lactation, illustrated,
# Nearest to powers: junta, independence, hooke, piping, lenin, cuzco, sentencing, breitman,
# Nearest to nobel: physiology, recipient, chemist, aviation, medicine, prize, businessman, luc,
# Nearest to liberal: democrats, mps, andriessen, electorate, coalition, lieberman, sadd, endorse,
# Nearest to proposed: interphase, ghosh, ethers, interdiction, whewell, comte, tubular, modeling,
# Nearest to universe: nucleosynthesis, cosmological, abrahamic, absolute, friend, derivational, probes, impersonal,
# Nearest to recorded: song, ephraim, downstream, apes, tulane, meza, gastroenterology, gloucestershire,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0466 0.0774 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0142 0.0767 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0283 0.0766 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0663 0.0763 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0707 0.0762 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0928 0.0763 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0463 0.0763 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1157 0.0758 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0770 0.0758 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0324 0.0761 sec/batch
# Nearest to that: remodeling, filming, measurable, be, far, extremal, selfish, until,
# Nearest to who: adduce, aide, certificates, unsuspecting, consultant, risky, hurting, mithras,
# Nearest to these: spellman, petitioner, sarai, number, immanent, side, same, cephalon,
# Nearest to however: panyu, manipulating, interlanguage, pathogens, rial, crittenden, figuring, moderately,
# Nearest to in: the, from, second, of, by, is, petition, a,
# Nearest to by: in, carabineros, determination, impeached, vote, four, squirrels, zero,
# Nearest to d: delius, hone, romain, curta, gattaca, kearney, monoxide, marko,
# Nearest to may: staking, inflicting, kinematics, not, champs, contexts, serviceable, integer,
# Nearest to professional: baseball, braves, awarded, overstepped, unicef, cookbookwiki, managers, effectiveness,
# Nearest to animals: humans, lipid, socio, lactation, genetics, mitochondrion, microclimates, illustrated,
# Nearest to powers: junta, independence, piping, hooke, president, cuzco, lenin, sentencing,
# Nearest to nobel: physiology, recipient, chemist, aviation, businessman, manufacturer, medicine, prize,
# Nearest to liberal: democrats, mps, coalition, endorse, electorate, andriessen, lieberman, sadd,
# Nearest to proposed: interphase, ghosh, ethers, modeling, tubular, parerga, algae, stereochemistry,
# Nearest to universe: nucleosynthesis, cosmological, abrahamic, friend, derivational, hypotheses, probes, reality,
# Nearest to recorded: song, downstream, ephraim, apes, meza, tulane, gastroenterology, visuals,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0421 0.0767 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1087 0.0761 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0482 0.0755 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0544 0.0755 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0803 0.0754 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0312 0.0758 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0680 0.0758 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0702 0.0758 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0889 0.0759 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0766 0.0762 sec/batch
# Nearest to that: remodeling, until, far, extremal, awaiting, believed, filming, be,
# Nearest to who: adduce, grandfather, mithras, aide, profiting, tobruk, consultant, wwf,
# Nearest to these: spellman, petitioner, sarai, number, cephalon, side, exposing, studd,
# Nearest to however: panyu, crittenden, interlanguage, figuring, within, manipulating, outright, rial,
# Nearest to in: the, from, of, second, is, by, lutheran, petition,
# Nearest to by: impeached, in, carabineros, determination, four, february, judaean, creation,
# Nearest to d: delius, hone, romain, gattaca, curta, jorge, monoxide, volution,
# Nearest to may: inflicting, staking, not, kinematics, contexts, champs, leopoldo, artiodactyla,
# Nearest to professional: baseball, braves, awarded, unicef, overstepped, cookbookwiki, managers, baylor,
# Nearest to animals: humans, lipid, lactation, genetics, microclimates, mitochondrion, socio, illustrated,
# Nearest to powers: junta, independence, head, hooke, president, cuzco, piping, rumored,
# Nearest to nobel: physiology, recipient, aviation, businessman, chemist, medicine, wagstaff, manufacturer,
# Nearest to liberal: democrats, mps, coalition, andriessen, endorse, sadd, lieberman, electorate,
# Nearest to proposed: interphase, ghosh, psionic, ethers, parerga, gassendi, paymaster, algae,
# Nearest to universe: nucleosynthesis, cosmological, friend, abrahamic, probes, mythological, grams, derivational,
# Nearest to recorded: song, downstream, ephraim, apes, meza, tulane, gloucestershire, wolfowitz,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0404 0.0764 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0432 0.0761 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0514 0.0759 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0966 0.0759 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0224 0.0760 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1195 0.0761 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1499 0.0760 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0573 0.0762 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0315 0.0758 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0513 0.0759 sec/batch
# Nearest to that: remodeling, until, filming, be, awaiting, far, submitted, affliction,
# Nearest to who: adduce, consultant, certificates, grandfather, aide, hurting, divest, polymaths,
# Nearest to these: spellman, petitioner, sarai, number, immanent, cephalon, differ, same,
# Nearest to however: panyu, crittenden, manipulating, within, figuring, pathogens, interlanguage, rial,
# Nearest to in: the, of, from, second, is, petition, by, woodhull,
# Nearest to by: carabineros, impeached, in, determination, judaean, cosgrave, election, february,
# Nearest to d: delius, hone, romain, gattaca, jorge, curta, marko, oshawa,
# Nearest to may: staking, kinematics, inflicting, champs, artiodactyla, contexts, leopoldo, integer,
# Nearest to professional: baseball, braves, cookbookwiki, awarded, unicef, baylor, overstepped, liverpudlians,
# Nearest to animals: humans, lipid, lactation, mitochondrion, microclimates, socio, genetics, pygmy,
# Nearest to powers: junta, independence, hooke, head, piping, modules, rumored, cuzco,
# Nearest to nobel: physiology, recipient, chemist, prize, businessman, medicine, manufacturer, aviation,
# Nearest to liberal: democrats, coalition, mps, sadd, andriessen, endorse, lieberman, electorate,
# Nearest to proposed: interphase, ghosh, gassendi, ethers, psionic, modeling, stereochemistry, interdiction,
# Nearest to universe: nucleosynthesis, cosmological, probes, abrahamic, friend, mythological, hypotheses, spartan,
# Nearest to recorded: song, downstream, ephraim, apes, meza, wolfowitz, gloucestershire, tulane,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9698 0.0766 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9918 0.0758 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0378 0.0757 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9774 0.0756 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0718 0.0757 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0286 0.0661 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0139 0.0756 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9941 0.0754 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0202 0.0752 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9596 0.0752 sec/batch
# Nearest to that: remodeling, until, be, far, relates, believed, catchphrases, absurdum,
# Nearest to who: adduce, grandfather, mithras, aide, foolish, saw, nigger, salo,
# Nearest to these: spellman, sarai, petitioner, number, cephalon, exposing, differ, side,
# Nearest to however: crittenden, panyu, manipulating, within, figuring, pathogens, amos, interlanguage,
# Nearest to in: the, second, of, from, by, is, a, with,
# Nearest to by: in, carabineros, impeached, the, for, judaean, squirrels, creation,
# Nearest to d: delius, hone, romain, jorge, gattaca, marko, politician, volution,
# Nearest to may: staking, kinematics, champs, inflicting, contexts, artiodactyla, jes, integer,
# Nearest to professional: baseball, cookbookwiki, braves, unicef, baylor, managers, overstepped, awarded,
# Nearest to animals: humans, lipid, lactation, microclimates, genetics, mitochondrion, socio, illustrated,
# Nearest to powers: junta, hooke, independence, piping, head, modules, rumored, cretian,
# Nearest to nobel: physiology, recipient, nobelprize, prize, chemist, laureate, businessman, aviation,
# Nearest to liberal: democrats, coalition, endorse, mps, andriessen, sadd, gustave, lieberman,
# Nearest to proposed: interphase, ghosh, psionic, modeling, stereochemistry, gassendi, ethers, algae,
# Nearest to universe: nucleosynthesis, cosmological, abrahamic, probes, mythological, reality, hypotheses, friend,
# Nearest to recorded: song, downstream, ephraim, apes, meza, gloucestershire, tulane, bactrian,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0004 0.0758 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9514 0.0751 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0088 0.0749 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0242 0.0749 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0041 0.0750 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9974 0.0754 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8957 0.0754 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9485 0.0755 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9464 0.0751 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9730 0.0754 sec/batch
# Nearest to that: remodeling, until, be, far, measurable, causal, filming, absurdum,
# Nearest to who: adduce, certificates, consultant, aide, grandfather, divest, unsuspecting, wwf,
# Nearest to these: spellman, number, petitioner, sarai, side, differ, cephalon, are,
# Nearest to however: within, crittenden, manipulating, panyu, figuring, pathogens, moderately, pulau,
# Nearest to in: the, is, second, of, from, known, by, with,
# Nearest to by: in, carabineros, the, zero, four, mayor, for, determination,
# Nearest to d: hone, delius, romain, gattaca, curta, jorge, marko, ir,
# Nearest to may: staking, inflicting, champs, not, kinematics, artiodactyla, constipation, contexts,
# Nearest to professional: baseball, braves, cookbookwiki, unicef, managers, subkey, baylor, awarded,
# Nearest to animals: humans, lipid, lactation, genetics, socio, mitochondrion, microclimates, whalers,
# Nearest to powers: junta, independence, hooke, modules, head, piping, instance, iff,
# Nearest to nobel: physiology, recipient, nobelprize, prize, businessman, chemist, faggot, polonium,
# Nearest to liberal: democrats, coalition, mps, electorate, endorse, sadd, andriessen, tightened,
# Nearest to proposed: interphase, ghosh, stereochemistry, paymaster, modeling, psionic, ethers, whewell,
# Nearest to universe: nucleosynthesis, cosmological, probes, abrahamic, grams, mythological, absolute, reality,
# Nearest to recorded: song, downstream, ephraim, apes, gastroenterology, titled, meza, album,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0076 0.0763 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0252 0.0753 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9881 0.0757 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0144 0.0755 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0228 0.0756 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9637 0.0756 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9902 0.0754 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0075 0.0756 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9775 0.0754 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9930 0.0755 sec/batch
# Nearest to that: remodeling, be, far, filming, until, absurdum, being, a,
# Nearest to who: adduce, consultant, certificates, chose, aide, saw, salo, nigger,
# Nearest to these: spellman, number, petitioner, sarai, are, exposing, book, differ,
# Nearest to however: crittenden, panyu, within, manipulating, figuring, pulau, moderately, amos,
# Nearest to in: the, of, is, with, second, from, a, by,
# Nearest to by: in, the, carabineros, impeached, four, for, zero, judaean,
# Nearest to d: hone, delius, romain, gattaca, politician, jorge, marko, curta,
# Nearest to may: staking, not, champs, inflicting, kinematics, contexts, click, glycogenolysis,
# Nearest to professional: baseball, cookbookwiki, braves, unicef, baylor, managers, awarded, effectiveness,
# Nearest to animals: humans, lipid, genetics, mitochondrion, lactation, whalers, microclimates, socio,
# Nearest to powers: junta, independence, modules, hooke, head, piping, instance, immaterial,
# Nearest to nobel: physiology, recipient, prize, nobelprize, businessman, laureate, manufacturer, medicine,
# Nearest to liberal: democrats, coalition, mps, electorate, sadd, endorse, andriessen, lieberman,
# Nearest to proposed: interphase, psionic, stereochemistry, ghosh, algae, ethers, magnify, modeling,
# Nearest to universe: nucleosynthesis, cosmological, probes, abrahamic, reality, hypotheses, grams, mythological,
# Nearest to recorded: song, downstream, titled, album, ephraim, samir, hop, abn,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9931 0.0765 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9794 0.0759 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0106 0.0753 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0021 0.0752 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0295 0.0752 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9980 0.0754 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0032 0.0750 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9592 0.0753 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9751 0.0751 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0254 0.0752 sec/batch
# ...
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9234 0.0729 sec/batch
# Nearest to that: be, a, the, being, because, in, they, this,
# Nearest to who: so, adduce, salo, certificates, feasting, anger, fourteen, they,
# Nearest to these: are, some, differ, number, and, same, they, be,
# Nearest to however: been, within, it, figuring, overwhelming, be, controversial, recent,
# Nearest to in: the, a, of, by, is, with, from, and,
# Nearest to by: the, in, an, a, with, for, and, which,
# Nearest to d: hone, romain, curta, lectronique, oblige, delius, phosphate, marko,
# Nearest to may: not, or, rituals, calendars, hundredth, nutrients, kinematics, are,
# Nearest to professional: baseball, supposes, volleyball, women, ranks, diaz, skating, gymnastics,
# Nearest to animals: humans, mitochondrion, weasels, whalers, michaels, microclimates, lipid, desmond,
# Nearest to powers: brunei, refund, modules, hooke, godlike, melchett, instance, badges,
# Nearest to nobel: prize, physiology, recipient, laureate, nobelprize, contests, medicine, polonium,
# Nearest to liberal: democrats, coalition, mps, andriessen, neck, electorate, progressive, snedden,
# Nearest to proposed: paymaster, jaynes, psionic, tubular, stereochemistry, gough, predefined, novial,
# Nearest to universe: nucleosynthesis, cosmological, bang, grams, surprises, circling, unfalsifiable, arxiv,
# Nearest to recorded: song, downstream, record, labienus, samir, records, titled, xliv,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8713 0.0735 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8336 0.0728 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8103 0.0728 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8478 0.0728 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8733 0.0728 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8816 0.0728 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8376 0.0728 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8533 0.0728 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8760 0.0728 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8758 0.0730 sec/batch
# Nearest to that: be, a, the, being, in, has, because, this,
# Nearest to who: so, adduce, feasting, fourteen, salo, certificates, excepting, that,
# Nearest to these: are, differ, some, number, and, same, recent, mercenaries,
# Nearest to however: been, within, it, the, be, overwhelming, controversial, only,
# Nearest to in: the, of, a, with, is, and, from, by,
# Nearest to by: the, in, an, a, with, and, which, of,
# Nearest to d: hone, lectronique, oblige, curta, romain, delius, phosphate, rst,
# Nearest to may: not, or, artiodactyla, glycogenolysis, kinematics, calendars, are, rituals,
# Nearest to professional: baseball, supposes, volleyball, diaz, women, skating, ranks, baylor,
# Nearest to animals: humans, mitochondrion, michaels, weasels, whalers, microclimates, lactation, desmond,
# Nearest to powers: brunei, refund, head, president, hooke, planckian, richardson, godlike,
# Nearest to nobel: prize, physiology, recipient, nobelprize, laureate, contests, polonium, medicine,
# Nearest to liberal: democrats, coalition, mps, andriessen, neck, snedden, progressive, electorate,
# Nearest to proposed: this, paymaster, jaynes, gough, proposals, won, novial, kosrae,
# Nearest to universe: nucleosynthesis, cosmological, bang, grams, surprises, arxiv, mythological, unfalsifiable,
# Nearest to recorded: song, record, labienus, downstream, samir, titled, records, xliv,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8366 0.0735 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8397 0.0728 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8448 0.0728 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8501 0.0729 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8551 0.0729 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8744 0.0731 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9587 0.0730 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9107 0.0729 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9379 0.0729 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8083 0.0729 sec/batch
# Nearest to that: be, a, the, has, only, because, in, being,
# Nearest to who: so, feasting, adduce, been, fourteen, yoruba, certificates, salo,
# Nearest to these: are, differ, mercenaries, some, number, recent, and, rheims,
# Nearest to however: been, within, the, was, it, overwhelming, only, be,
# Nearest to in: the, of, a, from, and, with, by, is,
# Nearest to by: the, in, an, and, for, with, a, which,
# Nearest to d: hone, romain, oblige, lectronique, sculptor, curta, wilmot, delius,
# Nearest to may: not, calendars, champs, jes, magistracies, or, artiodactyla, glycogenolysis,
# Nearest to professional: baseball, volleyball, supposes, diaz, women, ranks, baylor, basketball,
# Nearest to animals: humans, mitochondrion, weasels, michaels, whalers, lactation, microclimates, desmond,
# Nearest to powers: brunei, refund, hooke, planckian, godlike, richardson, juvenile, based,
# Nearest to nobel: prize, physiology, recipient, laureate, nobelprize, medicine, contests, polonium,
# Nearest to liberal: democrats, coalition, mps, neck, andriessen, snedden, danny, progressive,
# Nearest to proposed: paymaster, gough, won, proposals, jaynes, novial, kosrae, automakers,
# Nearest to universe: nucleosynthesis, cosmological, bang, surprises, grams, mythological, arxiv, unfalsifiable,
# Nearest to recorded: song, record, downstream, labienus, titled, records, samir, xliv,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8376 0.0736 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8350 0.0729 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7876 0.0729 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8747 0.0730 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8642 0.0730 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8185 0.0730 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9157 0.1014 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8254 0.0728 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8720 0.0727 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8068 0.0728 sec/batch
# Nearest to that: be, a, the, until, in, because, they, being,
# Nearest to who: that, adduce, so, been, fourteen, to, feasting, mustafa,
# Nearest to these: are, mercenaries, differ, some, recent, such, number, rheims,
# Nearest to however: been, within, be, it, overwhelming, was, only, though,
# Nearest to in: the, of, a, by, with, from, second, and,
# Nearest to by: the, in, a, an, with, for, of, and,
# Nearest to d: romain, hone, lectronique, sculptor, b, oblige, wilmot, curta,
# Nearest to may: calendars, not, artiodactyla, or, rituals, champs, are, hundredth,
# Nearest to professional: baseball, volleyball, diaz, supposes, technically, ranks, baylor, women,
# Nearest to animals: humans, michaels, mitochondrion, whalers, weasels, lactation, microclimates, echidna,
# Nearest to powers: brunei, refund, godlike, richardson, planckian, juvenile, hooke, bulgaria,
# Nearest to nobel: prize, physiology, recipient, laureate, nobelprize, contests, polonium, medicine,
# Nearest to liberal: democrats, coalition, snedden, neck, andriessen, mps, progressive, sadd,
# Nearest to proposed: paymaster, proposals, jaynes, gough, novial, ethers, kosrae, corbett,
# Nearest to universe: nucleosynthesis, cosmological, bang, surprises, grams, arxiv, unfalsifiable, mythological,
# Nearest to recorded: song, record, downstream, records, titled, labienus, xliv, samir,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8435 0.0735 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7836 0.0727 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8416 0.0729 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7927 0.0728 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8355 0.0727 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8323 0.0728 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8673 0.0728 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7796 0.0727 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8073 0.0728 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8062 0.0728 sec/batch
# Nearest to that: be, a, the, this, is, if, of, in,
# Nearest to who: that, adduce, been, salo, so, fourteen, certificates, feasting,
# Nearest to these: are, such, some, number, differ, and, mercenaries, same,
# Nearest to however: been, within, be, it, the, was, only, controversial,
# Nearest to in: the, of, a, is, by, from, with, and,
# Nearest to by: the, in, a, an, for, with, which, of,
# Nearest to d: hone, romain, oblige, lectronique, rst, curta, equivalents, kearney,
# Nearest to may: not, calendars, or, a, hundredth, this, rituals, are,
# Nearest to professional: baseball, volleyball, supposes, women, ranks, diaz, skating, baylor,
# Nearest to animals: humans, michaels, mitochondrion, weasels, whalers, lipid, desmond, lactation,
# Nearest to powers: brunei, refund, godlike, richardson, planckian, melchett, juvenile, hooke,
# Nearest to nobel: prize, physiology, recipient, laureate, nobelprize, contests, polonium, medicine,
# Nearest to liberal: democrats, coalition, andriessen, mps, snedden, progressive, neck, danny,
# Nearest to proposed: paymaster, proposals, jaynes, predefined, novial, tubular, newall, yalu,
# Nearest to universe: nucleosynthesis, cosmological, bang, arxiv, grams, surprises, unfalsifiable, circling,
# Nearest to recorded: song, record, records, downstream, labienus, titled, tolerant, samir,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7493 0.0735 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8220 0.0729 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8635 0.0728 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8356 0.0728 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8373 0.0728 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8984 0.0728 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8647 0.0729 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8165 0.0728 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8497 0.0730 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8245 0.0729 sec/batch
# Nearest to that: be, a, the, in, has, is, this, only,
# Nearest to who: that, been, adduce, so, salo, fulfills, time, fourteen,
# Nearest to these: are, differ, number, some, mercenaries, as, and, such,
# Nearest to however: been, within, it, controversial, be, the, was, although,
# Nearest to in: the, of, a, by, is, from, with, known,
# Nearest to by: the, in, an, for, with, a, is, of,
# Nearest to d: hone, lectronique, romain, oblige, rimmed, curta, chymotrypsin, equivalents,
# Nearest to may: not, or, calendars, artiodactyla, magistracies, hundredth, this, its,
# Nearest to professional: baseball, supposes, volleyball, diaz, women, ranks, skating, enclosures,
# Nearest to animals: humans, mitochondrion, michaels, weasels, whalers, lipid, desmond, microclimates,
# Nearest to powers: brunei, godlike, refund, planckian, based, president, richardson, bulgaria,
# Nearest to nobel: prize, physiology, laureate, recipient, nobelprize, contests, polonium, imt,
# Nearest to liberal: democrats, coalition, andriessen, mps, snedden, neck, progressive, danny,
# Nearest to proposed: proposals, paymaster, novial, jaynes, this, ethers, kosrae, yalu,
# Nearest to universe: nucleosynthesis, cosmological, bang, grams, arxiv, surprises, ccg, unfalsifiable,
# Nearest to recorded: song, record, records, titled, labienus, downstream, peaked, samir,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8719 0.0736 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8040 0.0728 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8072 0.0730 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8654 0.0729 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8461 0.0728 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8301 0.0767 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8440 0.0733 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8470 0.0732 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8331 0.0732 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8158 0.0732 sec/batch
# Nearest to that: be, the, a, in, only, this, is, has,
# Nearest to who: that, been, so, they, fourteen, feasting, adduce, time,
# Nearest to these: are, and, differ, some, as, mercenaries, such, same,
# Nearest to however: been, be, within, the, it, only, that, for,
# Nearest to in: the, of, a, from, by, with, and, is,
# Nearest to by: the, in, an, with, for, a, and, of,
# Nearest to d: hone, rimmed, oblige, curta, lectronique, chymotrypsin, romain, phosphate,
# Nearest to may: not, or, its, this, usually, calendars, a, glycogenolysis,
# Nearest to professional: baseball, women, volleyball, diaz, skating, supposes, enclosures, aerobatics,
# Nearest to animals: humans, michaels, mitochondrion, whalers, weasels, lipid, lactation, echidna,
# Nearest to powers: brunei, godlike, based, richardson, refund, planckian, melchett, wrestlemania,
# Nearest to nobel: prize, physiology, recipient, laureate, nobelprize, contests, imt, medicine,
# Nearest to liberal: democrats, coalition, andriessen, mps, neck, snedden, progressive, danny,
# Nearest to proposed: proposals, paymaster, jaynes, novial, gough, ethers, this, newall,
# Nearest to universe: nucleosynthesis, cosmological, bang, arxiv, surprises, grams, mythological, unfalsifiable,
# Nearest to recorded: song, record, records, titled, labienus, downstream, xliv, samir,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8542 0.0739 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8453 0.0732 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9129 0.0734 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9524 0.0734 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8860 0.0732 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8539 0.0733 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7835 0.0732 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8385 0.0731 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.6965 0.0733 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8700 0.0733 sec/batch
# Nearest to that: be, a, the, only, this, if, is, in,
# Nearest to who: that, so, feasting, adduce, they, yoruba, upu, salo,
# Nearest to these: are, such, differ, as, and, some, mercenaries, recent,
# Nearest to however: been, within, be, it, that, was, the, only,
# Nearest to in: the, of, a, from, and, with, by, is,
# Nearest to by: the, in, an, a, with, for, and, of,
# Nearest to d: romain, b, oblige, lectronique, sculptor, rst, curta, hone,
# Nearest to may: not, calendars, artiodactyla, this, crows, remaining, hundredth, abc,
# Nearest to professional: baseball, diaz, supposes, volleyball, women, skating, enclosures, aerobatics,
# Nearest to animals: humans, mitochondrion, whalers, michaels, echidna, lactation, weasels, lipid,
# Nearest to powers: brunei, godlike, richardson, planckian, based, refund, juvenile, melchett,
# Nearest to nobel: prize, physiology, recipient, laureate, nobelprize, contests, imt, polonium,
# Nearest to liberal: democrats, coalition, andriessen, progressive, neck, snedden, mps, sadd,
# Nearest to proposed: proposals, paymaster, jaynes, novial, gough, ethers, won, papandreou,
# Nearest to universe: nucleosynthesis, cosmological, arxiv, bang, grams, unfalsifiable, surprises, mythological,
# Nearest to recorded: song, record, records, titled, downstream, labienus, albums, xliv,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8354 0.0739 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8298 0.0733 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
